# %%
import numpy as np
from matplotlib import pyplot as plt
import mxnet
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-7-a2b8a0b419cd> in <module>()
#       1 import numpy as np
#       2 from matplotlib import pyplot as plt
# ----> 3 import mxnet
#
# ImportError: No module named mxnet

# %%
fig1 = plt.figure() # create a figure with the default size 

im1 = np.random.rand(5,5)
ax1 = fig1.add_subplot(2,2,1) 
ax1.imshow(im1, interpolation='none')
ax1.set_title('5 X 5')

im2 = np.random.rand(100,100)
ax2 = fig1.add_subplot(2,2,2)
ax2.imshow(im2, interpolation='none')
ax2.set_title('100 X 100')
plt.show()

# %%
# UNDERSTANDING imshow function - OUTSIDE TOPIC
# Try the following
#  --- plt.imshow(np.random.rand(100, 10), interpolation='nearest', aspect = 'auto' )
#  --- plt.imshow(np.random.rand(100, 10),  aspect = 'auto' )
#  --- plt.imshow(np.random.rand(100, 10), interpolation='nearest' )
#  --- plt.imshow(np.random.rand(10, 100), interpolation='nearest' )
#  --- plt.imshow(np.random.rand(1, 100), interpolation='nearest' , aspect='auto')
#  --- plt.imshow(np.random.rand(1, 100), interpolation='nearest')
#  --- plt.imshow(np.random.rand(100, 100))
plt.imshow(np.random.rand(100, 100) )
plt.show()
