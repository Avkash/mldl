# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

# %%
import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# ('Found and verified', 'text8.zip')

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

words = read_data(filename)
print('Data size', len(words))
# Out:
# ('Data size', 17005207)

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# ('Most common words (+UNK)', [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)])
# ('Sample data', [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156], ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against'])

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# (3084, 'originated', '->', 12, 'as')
# (3084, 'originated', '->', 5239, 'anarchism')
# (12, 'as', '->', 3084, 'originated')
# (12, 'as', '->', 6, 'a')
# (6, 'a', '->', 12, 'as')
# (6, 'a', '->', 195, 'term')
# (195, 'term', '->', 6, 'a')
# (195, 'term', '->', 2, 'of')

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

# %%
graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                     num_sampled, vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5.1: Lets setup training step
# 
#  Note: this will take about 30 minutes in EC2 G2 Instance 
# 
num_steps = 100001

# %%
# Step 5.2: Begin training.
with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print("Initialized")

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# ('Average loss at step ', 0, ': ', 242.21406555175781)
# Nearest to they: extend, areas, badlands, cereal, experiencing, esoteric, whistling, bibliographic,
# Nearest to been: take, bonnet, biathletes, nobles, yell, sculpted, unimpeded, nadu,
# Nearest to some: separation, vicinity, parastatal, trailed, rocker, machen, arkham, sidespin,
# Nearest to this: minicomputer, camelot, humanitarian, pilgrim, azores, snow, palmas, puente,
# Nearest to have: speculators, legality, deimos, brigade, gibbons, proxima, scarab, axons,
# Nearest to nine: tajik, mingling, caen, imaginative, mounted, wine, scary, warlike,
# Nearest to will: battalions, bormann, sentience, hires, lizards, honesty, lucifer, copious,
# Nearest to during: taj, meson, gosford, schneider, megaliths, singh, reductionist, asic,
# Nearest to for: manufacture, internetwork, subway, geezer, puckett, ethnology, christiane, accommodated,
# Nearest to and: tiles, aragorn, joanne, scantily, ultimate, than, jair, moustache,
# Nearest to two: quo, edouard, epr, e, argentines, collectivisation, up, saul,
# Nearest to to: sigma, anachronism, icftu, deposited, glory, boucher, tsu, schellenberg,
# Nearest to used: emma, situs, sunshine, edo, elects, polluting, nicosia, marbury,
# Nearest to over: cimbri, retribution, darboux, hoboken, matching, badgers, nicolay, dissociatives,
# Nearest to are: democrats, off, litigation, standardization, walk, multinational, declaring, xanadu,
# Nearest to is: voices, titan, medlineplus, versailles, hillel, jessica, smashing, imaginative,
# ('Average loss at step ', 2000, ': ', 114.22857474803925)
# ('Average loss at step ', 4000, ': ', 52.816382940530779)
# ('Average loss at step ', 6000, ': ', 33.12405156111717)
# ('Average loss at step ', 8000, ': ', 23.728039767980576)
# ('Average loss at step ', 10000, ': ', 17.669224481821061)
# Nearest to they: extend, areas, x, he, gravity, badlands, esoteric, argues,
# Nearest to been: yoga, vowels, be, take, quest, tucker, oecs, aramaic,
# Nearest to some: separation, quote, represented, china, arkham, sharia, carry, mixture,
# Nearest to this: the, a, gone, it, humanitarian, occur, gland, identify,
# Nearest to have: axons, is, legality, tissue, had, be, advocated, finalist,
# Nearest to nine: gland, zero, victoriae, reginae, asterism, agave, vs, mengele,
# Nearest to will: battalions, honesty, sigma, and, bormann, ksc, hires, headed,
# Nearest to during: of, from, frontal, trials, cities, victoriae, schneider, yeast,
# Nearest to for: of, in, and, on, gland, from, victoriae, agave,
# Nearest to and: of, in, or, UNK, the, from, with, one,
# Nearest to two: one, reginae, vs, nine, victoriae, gland, solstice, six,
# Nearest to to: and, grasp, sigma, from, recognized, reverse, in, athenian,
# Nearest to used: emma, vs, firm, fish, whom, ox, staging, essential,
# Nearest to over: vs, diagram, solstice, tango, gland, reginae, influential, drew,
# Nearest to are: is, was, gland, condor, mathbf, off, bernard, walk,
# Nearest to is: was, in, ho, are, analogue, roosevelt, finalist, as,
# ('Average loss at step ', 12000, ': ', 14.083679490089416)
# ('Average loss at step ', 14000, ': ', 11.666561373472213)
# ('Average loss at step ', 16000, ': ', 9.7772750980854042)
# ('Average loss at step ', 18000, ': ', 8.5561936920881276)
# ('Average loss at step ', 20000, ': ', 7.8339699718952183)
# Nearest to they: he, extend, that, it, gravity, bailey, also, you,
# Nearest to been: be, by, yoga, bonnet, trough, vowels, quest, were,
# Nearest to some: polyhedra, the, one, dasyprocta, separation, quote, baruch, akm,
# Nearest to this: the, a, it, aquila, gone, which, one, any,
# Nearest to have: had, be, are, legality, do, is, tissue, aquila,
# Nearest to nine: eight, seven, zero, six, five, four, gland, three,
# Nearest to will: battalions, agouti, and, polyhedra, honesty, passengers, ksc, would,
# Nearest to during: from, of, in, on, and, at, frontal, between,
# Nearest to for: in, and, of, on, with, by, into, as,
# Nearest to and: or, in, agouti, of, with, polyhedra, for, six,
# Nearest to two: five, three, eight, six, one, four, nine, zero,
# Nearest to to: in, and, for, grasp, agouti, reverse, with, from,
# Nearest to used: emma, fortresses, firm, vs, whom, analogue, staging, dasyprocta,
# Nearest to over: diagram, matching, solstice, vs, tango, of, gland, influential,
# Nearest to are: is, were, was, astoria, aquila, but, have, condor,
# Nearest to is: was, are, has, agouti, by, in, absalom, aquila,
# ('Average loss at step ', 22000, ': ', 7.1435807801485058)
# ('Average loss at step ', 24000, ': ', 7.0234301267862316)
# ('Average loss at step ', 26000, ': ', 6.6458357206583027)
# ('Average loss at step ', 28000, ': ', 6.2125882097482679)
# ('Average loss at step ', 30000, ': ', 6.1763879276514055)
# Nearest to they: he, it, we, you, there, also, not, extend,
# Nearest to been: be, by, were, bonnet, yoga, was, trough, vowels,
# Nearest to some: polyhedra, the, trinomial, carry, arrangers, many, quote, these,
# Nearest to this: the, it, a, which, any, aquila, gone, occur,
# Nearest to have: had, be, are, do, legality, has, acadia, were,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to will: battalions, would, may, agouti, can, passengers, polyhedra, honesty,
# Nearest to during: from, in, at, of, on, between, and, after,
# Nearest to for: of, in, and, with, on, through, by, from,
# Nearest to and: or, in, of, s, agouti, from, but, thyestes,
# Nearest to two: four, three, five, six, one, eight, seven, zero,
# Nearest to to: for, can, agouti, would, nine, codeine, not, in,
# Nearest to used: aba, emma, fortresses, firm, whom, fathers, staging, elects,
# Nearest to over: matching, diagram, of, solstice, vs, tango, schema, anaheim,
# Nearest to are: were, is, have, was, astoria, aquila, but, swimming,
# Nearest to is: was, are, has, aquila, analogue, agouti, were, as,
# ('Average loss at step ', 32000, ': ', 5.8448811931610107)
# ('Average loss at step ', 34000, ': ', 5.8258334813117978)
# ('Average loss at step ', 36000, ': ', 5.7290167911052707)
# ('Average loss at step ', 38000, ': ', 5.2447380512952808)
# ('Average loss at step ', 40000, ': ', 5.4713171864748)
# Nearest to they: he, you, it, there, we, not, guderian, also,
# Nearest to been: be, were, by, was, bonnet, yoga, trough, vowels,
# Nearest to some: many, polyhedra, these, the, janitor, carry, any, trinomial,
# Nearest to this: the, which, it, that, any, aquila, a, lemmy,
# Nearest to have: had, be, are, has, were, do, guderian, legality,
# Nearest to nine: eight, seven, six, zero, five, four, three, recitative,
# Nearest to will: battalions, would, can, may, passengers, agouti, honesty, ova,
# Nearest to during: from, in, at, on, of, after, between, against,
# Nearest to for: in, of, through, from, or, gland, with, into,
# Nearest to and: or, but, in, thyestes, agouti, recitative, trinomial, six,
# Nearest to two: three, four, five, six, one, eight, seven, zero,
# Nearest to to: grasp, codeine, can, agouti, for, not, nine, seven,
# Nearest to used: aba, analogue, fortresses, emma, celebrations, but, whom, firm,
# Nearest to over: matching, diagram, solstice, vs, tango, schema, sfor, of,
# Nearest to are: were, is, have, was, but, bernard, aquila, mishnayot,
# Nearest to is: was, are, has, lemmy, aquila, analogue, agouti, by,
# ('Average loss at step ', 42000, ': ', 5.3058485989570618)
# ('Average loss at step ', 44000, ': ', 5.2968400857448579)
# ('Average loss at step ', 46000, ': ', 5.2481728546619415)
# ('Average loss at step ', 48000, ': ', 5.0239916141033172)
# ('Average loss at step ', 50000, ': ', 5.1615013575553892)
# Nearest to they: he, we, you, there, it, not, guderian, also,
# Nearest to been: be, was, were, by, bonnet, yoga, trough, vowels,
# Nearest to some: many, these, polyhedra, the, naaman, several, janitor, carry,
# Nearest to this: which, it, the, thibetanus, that, any, aquila, a,
# Nearest to have: had, be, has, are, were, guderian, do, by,
# Nearest to nine: eight, seven, six, four, five, zero, three, one,
# Nearest to will: would, can, may, battalions, passengers, agouti, prism, could,
# Nearest to during: in, from, at, after, on, against, of, between,
# Nearest to for: in, through, of, from, or, parapsychology, with, gland,
# Nearest to and: or, but, thibetanus, tabula, agouti, thyestes, seven, in,
# Nearest to two: three, four, one, six, five, eight, seven, zero,
# Nearest to to: codeine, can, agouti, would, could, nine, grasp, not,
# Nearest to used: aba, fortresses, celebrations, analogue, but, gendarmerie, emma, malaysian,
# Nearest to over: diagram, matching, cimbri, subjective, solstice, schema, agouti, vs,
# Nearest to are: were, is, have, was, be, aquila, bernard, swimming,
# Nearest to is: was, are, has, lemmy, analogue, aquila, agouti, were,
# ('Average loss at step ', 52000, ': ', 5.1740286155939099)
# ('Average loss at step ', 54000, ': ', 5.0978473275899887)
# ('Average loss at step ', 56000, ': ', 5.0495076222419737)
# ('Average loss at step ', 58000, ': ', 5.0963606002330781)
# ('Average loss at step ', 60000, ': ', 4.9419148576855658)
# Nearest to they: he, there, we, you, it, not, guderian, who,
# Nearest to been: be, was, by, were, bonnet, yoga, trough, become,
# Nearest to some: many, these, the, callithrix, naaman, polyhedra, several, any,
# Nearest to this: which, it, the, that, callithrix, thibetanus, any, aquila,
# Nearest to have: had, has, be, are, were, do, guderian, callithrix,
# Nearest to nine: eight, six, seven, four, five, zero, three, callithrix,
# Nearest to will: would, can, may, battalions, could, agouti, passengers, prism,
# Nearest to during: in, at, after, from, on, against, within, of,
# Nearest to for: of, callithrix, michelob, or, through, gland, in, avl,
# Nearest to and: or, but, callithrix, tabula, trinomial, thyestes, cebus, michelob,
# Nearest to two: three, four, five, six, one, eight, seven, callithrix,
# Nearest to to: michelob, callithrix, not, agouti, would, nine, grasp, codeine,
# Nearest to used: aba, marmoset, microcebus, gendarmerie, but, cebus, celebrations, analogue,
# Nearest to over: matching, diagram, cimbri, callithrix, subjective, solstice, microcebus, schema,
# Nearest to are: were, is, have, be, callithrix, was, but, aquila,
# Nearest to is: was, are, callithrix, has, lemmy, aquila, analogue, agouti,
# ('Average loss at step ', 62000, ': ', 4.8130431863069534)
# ('Average loss at step ', 64000, ': ', 4.7866684944629672)
# ('Average loss at step ', 66000, ': ', 4.9770513148307804)
# ('Average loss at step ', 68000, ': ', 4.9054956209659579)
# ('Average loss at step ', 70000, ': ', 4.777376809716225)
# Nearest to they: he, we, there, you, it, not, bokassa, who,
# Nearest to been: be, was, were, become, by, bonnet, yoga, vowels,
# Nearest to some: many, these, several, callithrix, all, polyhedra, naaman, any,
# Nearest to this: which, it, the, that, callithrix, one, any, thibetanus,
# Nearest to have: had, has, are, were, be, do, sequestration, guderian,
# Nearest to nine: eight, six, seven, four, five, zero, three, callithrix,
# Nearest to will: would, can, may, battalions, could, agouti, thaler, might,
# Nearest to during: in, after, from, at, within, callithrix, on, flynt,
# Nearest to for: callithrix, of, in, michelob, through, and, or, anchors,
# Nearest to and: or, but, callithrix, thaler, trinomial, thyestes, recitative, aquila,
# Nearest to two: three, six, four, five, one, seven, eight, callithrix,
# Nearest to to: michelob, can, callithrix, codeine, would, agouti, not, grasp,
# Nearest to used: aba, marmoset, gendarmerie, cebus, microcebus, celebrations, seen, found,
# Nearest to over: matching, diagram, cimbri, subjective, callithrix, microcebus, six, solstice,
# Nearest to are: were, is, have, be, callithrix, was, aquila, including,
# Nearest to is: was, are, has, lemmy, callithrix, aquila, analogue, be,
# ('Average loss at step ', 72000, ': ', 4.7940628496408459)
# ('Average loss at step ', 74000, ': ', 4.7793875192999842)
# ('Average loss at step ', 76000, ': ', 4.8589364368915557)
# ('Average loss at step ', 78000, ': ', 4.7837719674110408)
# ('Average loss at step ', 80000, ': ', 4.8056908912658693)
# Nearest to they: he, we, there, you, it, who, not, guderian,
# Nearest to been: be, was, were, become, bonnet, by, yoga, nine,
# Nearest to some: many, these, several, all, callithrix, other, naaman, various,
# Nearest to this: which, it, the, callithrix, one, that, thibetanus, upanija,
# Nearest to have: had, has, be, were, are, do, sequestration, guderian,
# Nearest to nine: eight, seven, six, five, four, zero, callithrix, three,
# Nearest to will: would, can, may, could, battalions, must, might, thaler,
# Nearest to during: after, in, from, at, within, despite, callithrix, however,
# Nearest to for: callithrix, through, michelob, of, or, if, in, parapsychology,
# Nearest to and: or, but, callithrix, thaler, thibetanus, michelob, cebus, eight,
# Nearest to two: three, four, six, five, seven, one, eight, callithrix,
# Nearest to to: michelob, globemaster, can, codeine, nine, callithrix, agouti, would,
# Nearest to used: vec, aba, marmoset, gendarmerie, seen, cebus, microcebus, found,
# Nearest to over: matching, diagram, cimbri, callithrix, during, iit, subjective, six,
# Nearest to are: were, is, have, callithrix, be, although, including, contain,
# Nearest to is: was, has, are, lemmy, callithrix, aquila, be, analogue,
# ('Average loss at step ', 82000, ': ', 4.8062514810562131)
# ('Average loss at step ', 84000, ': ', 4.7734221125841136)
# ('Average loss at step ', 86000, ': ', 4.8032894448041912)
# ('Average loss at step ', 88000, ': ', 4.6908239152431488)
# ('Average loss at step ', 90000, ': ', 4.75312117421627)
# Nearest to they: he, we, there, you, it, not, who, she,
# Nearest to been: be, was, become, were, by, already, bonnet, yoga,
# Nearest to some: many, these, several, all, callithrix, naaman, any, most,
# Nearest to this: which, it, the, callithrix, thibetanus, one, any, that,
# Nearest to have: had, has, were, be, are, do, guderian, sequestration,
# Nearest to nine: eight, seven, six, five, four, zero, three, callithrix,
# Nearest to will: can, would, may, could, must, battalions, might, should,
# Nearest to during: in, after, from, at, within, under, however, despite,
# Nearest to for: of, callithrix, michelob, through, with, or, in, if,
# Nearest to and: or, but, callithrix, thibetanus, thaler, michelob, in, thyestes,
# Nearest to two: three, five, four, six, seven, one, eight, callithrix,
# Nearest to to: michelob, globemaster, callithrix, can, agouti, grasp, codeine, nine,
# Nearest to used: aba, vec, marmoset, seen, found, cebus, gendarmerie, known,
# Nearest to over: matching, diagram, subjective, callithrix, during, cimbri, iit, badges,
# Nearest to are: were, is, have, be, including, while, callithrix, although,
# Nearest to is: was, has, are, lemmy, callithrix, be, contains, analogue,
# ('Average loss at step ', 92000, ': ', 4.7203741699457167)
# ('Average loss at step ', 94000, ': ', 4.6224531686306003)
# ('Average loss at step ', 96000, ': ', 4.7248468418121341)
# ('Average loss at step ', 98000, ': ', 4.6222502090930941)
# ('Average loss at step ', 100000, ': ', 4.6820585016012188)
# Nearest to they: he, we, there, you, it, she, not, who,
# Nearest to been: be, become, was, already, were, by, had, bonnet,
# Nearest to some: many, these, several, all, callithrix, any, the, various,
# Nearest to this: which, it, the, that, callithrix, thibetanus, one, another,
# Nearest to have: had, has, were, are, be, do, sequestration, guderian,
# Nearest to nine: eight, seven, six, five, four, zero, three, thaler,
# Nearest to will: would, can, may, could, must, might, should, to,
# Nearest to during: in, after, from, at, within, under, despite, callithrix,
# Nearest to for: callithrix, michelob, through, or, of, and, if, with,
# Nearest to and: or, but, callithrix, while, michelob, thibetanus, tabula, cebus,
# Nearest to two: three, four, five, six, seven, one, eight, callithrix,
# Nearest to to: michelob, globemaster, callithrix, will, can, thaler, nine, could,
# Nearest to used: aba, marmoset, vec, found, known, cebus, seen, gendarmerie,
# Nearest to over: matching, diagram, callithrix, during, four, three, iit, subjective,
# Nearest to are: were, have, is, be, while, although, contain, include,
# Nearest to is: was, has, are, callithrix, lemmy, does, aquila, contains,

# %%
normalized_embeddings
# Out:
# <tf.Tensor 'div:0' shape=(50000, 128) dtype=float32>

# %%
final_embeddings[0]
# Out:
# array([ -6.83524460e-02,  -4.53818664e-02,  -2.09545586e-02,
#          3.21462192e-02,  -2.99066752e-02,  -3.41986604e-02,
#          1.18182153e-01,   1.19908378e-01,   2.53487471e-02,
#         -8.83340165e-02,   2.32653320e-02,  -1.59276053e-02,
#          2.85502374e-02,  -6.81130886e-02,   1.12543724e-01,
#         -1.15737833e-01,  -1.61071584e-01,  -1.65752247e-01,
#          1.89508095e-01,  -2.06081153e-04,  -8.27482417e-02,
#          1.29005325e-03,  -4.39204425e-02,  -6.58820989e-03,
#          5.74894920e-02,   1.17504105e-01,   7.01190904e-02,
#         -7.57340565e-02,  -2.09009703e-02,  -7.98203722e-02,
#          4.86628488e-02,   1.34274294e-03,   9.09733996e-02,
#          7.32456194e-03,   1.42077908e-01,  -9.98689979e-02,
#         -6.33872524e-02,  -4.71973531e-02,   1.68214247e-01,
#          1.47987553e-03,  -5.00640273e-02,  -4.87174019e-02,
#         -7.37541765e-02,  -1.53191566e-01,  -4.65406552e-02,
#         -1.76631436e-01,  -5.99808507e-02,   1.22958668e-01,
#          6.58119097e-02,   4.53184061e-02,  -1.22358263e-01,
#         -4.30106036e-02,   2.71909928e-04,   8.40888172e-02,
#          9.78184119e-02,  -1.27076134e-01,  -9.89941880e-03,
#          4.16073054e-02,   7.77229145e-02,  -4.11129259e-02,
#         -1.94584094e-02,  -1.15588773e-02,   1.38197299e-02,
#         -4.88850176e-02,   6.54538870e-02,  -2.84820795e-03,
#         -7.00858831e-02,  -6.17902130e-02,  -1.71949193e-02,
#         -1.78538516e-01,   2.27692686e-02,  -2.66176439e-03,
#         -3.08312103e-02,   1.35925427e-01,   1.36417076e-01,
#          3.01766582e-02,   5.28824627e-02,  -1.50382640e-02,
#         -6.30322695e-02,   1.17529906e-01,   2.40530949e-02,
#          1.17652439e-01,  -2.97504338e-03,   1.17821902e-01,
#          9.61626247e-02,  -1.18102103e-01,  -5.92095591e-02,
#          2.87151318e-02,   3.06581799e-03,  -1.54675230e-01,
#          1.81157947e-01,  -4.79486994e-02,  -3.82809341e-02,
#          4.00460027e-02,  -7.19374344e-02,  -8.85815248e-02,
#          5.36074191e-02,  -7.00127184e-02,   5.01165614e-02,
#         -5.18225841e-02,  -1.42988771e-01,  -4.50708605e-02,
#         -8.40961467e-04,  -5.72508946e-03,   1.35068446e-01,
#         -2.11897865e-01,  -8.28507766e-02,   3.82423177e-02,
#         -1.14513591e-01,   5.32142445e-02,  -8.62904533e-04,
#         -2.70528913e-01,  -1.26508763e-02,   1.50676388e-02,
#          9.48020592e-02,  -9.09397155e-02,  -4.76951785e-02,
#         -2.25284338e-01,  -2.19525713e-02,   3.66483927e-02,
#         -2.81572063e-02,  -2.85939462e-02,   1.15643837e-01,
#          9.06023085e-02,  -1.58699378e-01,  -1.24900080e-02,
#          6.32709637e-02,   2.02711411e-02], dtype=float32)

# %%
# Step 6: Visualize the embeddings.
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels)
